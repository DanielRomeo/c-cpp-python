# %% [markdown]
# # Graph Data structure

# %%
# Display the Routes example image
from IPython.display import Image
Image("graph_images/graph_example1.png")

# %% [markdown]
# ### Concerning the above image
# <p>The above image shows a graph of cities and the routes between them(airline routes) </p>

# %%
# Declare the routes:
# Routes is an aray of tuples
routes = [
    ("Mumbai", "Paris"),
    ("Mumbai", "Dubai"),
    ("Paris", "Dubai"),
    ("Paris", "New York"),
    ("Dubai", "New York"),
    ("New York", "Toronto")
]

# %% [markdown]
# The above method of declaring routes might be too expensive(especially if we're going to loop through all of them)
#
# ### Different way of declaring routes
# `routes2 = [
#     "mumbai": ["Paris", "Dubai"],
# ]`
#
# A better way would be to do the below:
